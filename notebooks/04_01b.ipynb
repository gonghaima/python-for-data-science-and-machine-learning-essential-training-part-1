# %%
pip install Matplotlib
# Out:
# Collecting Matplotlib
#   Downloading matplotlib-3.11.0-cp313-cp313-macosx_11_0_arm64.whl.metadata (80 kB)
# Collecting contourpy>=1.0.1 (from Matplotlib)
#   Downloading contourpy-1.3.3-cp313-cp313-macosx_11_0_arm64.whl.metadata (5.5 kB)
# Collecting cycler>=0.10 (from Matplotlib)
#   Downloading cycler-0.12.1-py3-none-any.whl.metadata (3.8 kB)
# Collecting fonttools>=4.22.0 (from Matplotlib)
#   Downloading fonttools-4.63.0-cp313-cp313-macosx_10_13_universal2.whl.metadata (118 kB)
# Collecting kiwisolver>=1.3.1 (from Matplotlib)
#   Downloading kiwisolver-1.5.0-cp313-cp313-macosx_11_0_arm64.whl.metadata (5.1 kB)
# Requirement already satisfied: numpy>=1.25 in /Users/stevengong/study/python-for-data-science-and-machine-learning-essential-training-part-1-3006708/.venv/lib/python3.13/site-packages (from Matplotlib) (2.5.0)
# Requirement already satisfied: packaging>=20.0 in /Users/stevengong/study/python-for-data-science-and-machine-learning-essential-training-part-1-3006708/.venv/lib/python3.13/site-packages (from Matplotlib) (26.2)
# Collecting pillow>=9 (from Matplotlib)
#   Downloading pillow-12.2.0-cp313-cp313-macosx_11_0_arm64.whl.metadata (8.8 kB)
# Collecting pyparsing>=3 (from Matplotlib)
#   Downloading pyparsing-3.3.2-py3-none-any.whl.metadata (5.8 kB)
# Requirement already satisfied: python-dateutil>=2.7 in /Users/stevengong/study/python-for-data-science-and-machine-learning-essential-training-part-1-3006708/.venv/lib/python3.13/site-packages (from Matplotlib) (2.9.0.post0)
# Requirement already satisfied: six>=1.5 in /Users/stevengong/study/python-for-data-science-and-machine-learning-essential-training-part-1-3006708/.venv/lib/python3.13/site-packages (from python-dateutil>=2.7->Matplotlib) (1.17.0)
# Downloading matplotlib-3.11.0-cp313-cp313-macosx_11_0_arm64.whl (9.3 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 9.3/9.3 MB 76.0 MB/s  0:00:00
# Downloading contourpy-1.3.3-cp313-cp313-macosx_11_0_arm64.whl (274 kB)
# Downloading cycler-0.12.1-py3-none-any.whl (8.3 kB)
# Downloading fonttools-4.63.0-cp313-cp313-macosx_10_13_universal2.whl (2.9 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 2.9/2.9 MB 81.8 MB/s  0:00:00
# Downloading kiwisolver-1.5.0-cp313-cp313-macosx_11_0_arm64.whl (64 kB)
# Downloading pillow-12.2.0-cp313-cp313-macosx_11_0_arm64.whl (4.7 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 4.7/4.7 MB 85.3 MB/s  0:00:00
# Downloading pyparsing-3.3.2-py3-none-any.whl (122 kB)
# Installing collected packages: pyparsing, pillow, kiwisolver, fonttools, cycler, contourpy, Matplotlib
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 7/7 [Matplotlib]7 [Matplotlib]
# Successfully installed Matplotlib-3.11.0 contourpy-1.3.3 cycler-0.12.1 fonttools-4.63.0 kiwisolver-1.5.0 pillow-12.2.0 pyparsing-3.3.2
# Note: you may need to restart the kernel to use updated packages.

# %%
pip install seaborn
# Out:
# Collecting seaborn
#   Downloading seaborn-0.13.2-py3-none-any.whl.metadata (5.4 kB)
# Requirement already satisfied: numpy!=1.24.0,>=1.20 in /Users/stevengong/study/python-for-data-science-and-machine-learning-essential-training-part-1-3006708/.venv/lib/python3.13/site-packages (from seaborn) (2.5.0)
# Requirement already satisfied: pandas>=1.2 in /Users/stevengong/study/python-for-data-science-and-machine-learning-essential-training-part-1-3006708/.venv/lib/python3.13/site-packages (from seaborn) (3.0.4)
# Requirement already satisfied: matplotlib!=3.6.1,>=3.4 in /Users/stevengong/study/python-for-data-science-and-machine-learning-essential-training-part-1-3006708/.venv/lib/python3.13/site-packages (from seaborn) (3.11.0)
# Requirement already satisfied: contourpy>=1.0.1 in /Users/stevengong/study/python-for-data-science-and-machine-learning-essential-training-part-1-3006708/.venv/lib/python3.13/site-packages (from matplotlib!=3.6.1,>=3.4->seaborn) (1.3.3)
# Requirement already satisfied: cycler>=0.10 in /Users/stevengong/study/python-for-data-science-and-machine-learning-essential-training-part-1-3006708/.venv/lib/python3.13/site-packages (from matplotlib!=3.6.1,>=3.4->seaborn) (0.12.1)
# Requirement already satisfied: fonttools>=4.22.0 in /Users/stevengong/study/python-for-data-science-and-machine-learning-essential-training-part-1-3006708/.venv/lib/python3.13/site-packages (from matplotlib!=3.6.1,>=3.4->seaborn) (4.63.0)
# Requirement already satisfied: kiwisolver>=1.3.1 in /Users/stevengong/study/python-for-data-science-and-machine-learning-essential-training-part-1-3006708/.venv/lib/python3.13/site-packages (from matplotlib!=3.6.1,>=3.4->seaborn) (1.5.0)
# Requirement already satisfied: packaging>=20.0 in /Users/stevengong/study/python-for-data-science-and-machine-learning-essential-training-part-1-3006708/.venv/lib/python3.13/site-packages (from matplotlib!=3.6.1,>=3.4->seaborn) (26.2)
# Requirement already satisfied: pillow>=9 in /Users/stevengong/study/python-for-data-science-and-machine-learning-essential-training-part-1-3006708/.venv/lib/python3.13/site-packages (from matplotlib!=3.6.1,>=3.4->seaborn) (12.2.0)
# Requirement already satisfied: pyparsing>=3 in /Users/stevengong/study/python-for-data-science-and-machine-learning-essential-training-part-1-3006708/.venv/lib/python3.13/site-packages (from matplotlib!=3.6.1,>=3.4->seaborn) (3.3.2)
# Requirement already satisfied: python-dateutil>=2.7 in /Users/stevengong/study/python-for-data-science-and-machine-learning-essential-training-part-1-3006708/.venv/lib/python3.13/site-packages (from matplotlib!=3.6.1,>=3.4->seaborn) (2.9.0.post0)
# Requirement already satisfied: six>=1.5 in /Users/stevengong/study/python-for-data-science-and-machine-learning-essential-training-part-1-3006708/.venv/lib/python3.13/site-packages (from python-dateutil>=2.7->matplotlib!=3.6.1,>=3.4->seaborn) (1.17.0)
# Downloading seaborn-0.13.2-py3-none-any.whl (294 kB)
# Installing collected packages: seaborn
# Successfully installed seaborn-0.13.2
# Note: you may need to restart the kernel to use updated packages.

# %%
import matplotlib.pyplot as plt
import seaborn as sns

from pandas import DataFrame
# Out:
# Matplotlib is building the font cache; this may take a moment.

# %%
data = {'names':['steve', 'john', 'richard', 'sarah', 'randy', 'micheal', 'julie'],
        'age':[20, 22, 20, 21, 24, 23, 22],
        'gender':['Male', 'Male', 'Male', 'Female', 'Male', 'Male', 'Female'],
        'rank':[2, 1, 4, 5, 3, 7, 6]}

df=DataFrame(data)
df
# Out:
#      names  age  gender  rank
# 0    steve   20    Male     2
# 1     john   22    Male     1
# 2  richard   20    Male     4
# 3    sarah   21  Female     5
# 4    randy   24    Male     3
# 5  micheal   23    Male     7
# 6    julie   22  Female     6

# %% [markdown]
# ### Matplotlib's Bar Chart

# %%
plt.bar(df['names'], df['age'])
plt.xlabel('Names')
plt.ylabel('Age')
plt.title('Comparing Ages')
plt.show()

# %%
plot = sns.barplot(data=df, x='names', y = 'age')
plot.set_title("Comparing Ages")
plt.show()

# %% [markdown]
# ### Line Plot Matplotlib

# %%
plt.plot(df['names'], df['age'])
plt.xlabel('Names')
plt.ylabel('Age')
plt.title('Comparing Ages')
plt.show()

# %% [markdown]
# ### Line Plot Seaborn

# %%
plot = sns.lineplot(data=df, x='names', y = 'age')
plt.show()

# %% [markdown]
# ### Pie Chart Matplotlib

# %%
plt.pie(df['age'], labels = df['names'])
plt.title("Age Comparison")
plt.show()

# %% [markdown]
# ### Pie Chart Seaborn

# %%
colors = sns.color_palette('pastel')[0:5]
plt.pie(df['age'], labels = df['names'], colors = colors)
plt.show()

# %%
就这样吧
